# %%
import pandas as pd
import numpy as np
import json

from app_store_scraper import AppStore
tinder = AppStore(country='us', app_name='tinder-dating-chat-friends', app_id='547702041')

tinder.review(sleep=1)
# Out:
# 2023-11-17 13:30:53,159 [INFO] Base - Initialised: AppStore('us', 'tinder-dating-chat-friends', 547702041)
# 2023-11-17 13:30:53,159 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/tinder-dating-chat-friends/id547702041
# 2023-11-17 13:30:59,370 [INFO] Base - [id:547702041] Fetched 100 reviews (100 fetched in total)
# 2023-11-17 13:31:05,805 [INFO] Base - [id:547702041] Fetched 200 reviews (200 fetched in total)
# 2023-11-17 13:31:12,163 [INFO] Base - [id:547702041] Fetched 300 reviews (300 fetched in total)
# 2023-11-17 13:31:18,625 [INFO] Base - [id:547702041] Fetched 400 reviews (400 fetched in total)
# 2023-11-17 13:31:25,147 [INFO] Base - [id:547702041] Fetched 500 reviews (500 fetched in total)
# 2023-11-17 13:31:32,717 [INFO] Base - [id:547702041] Fetched 600 reviews (600 fetched in total)
# 2023-11-17 13:31:39,392 [INFO] Base - [id:547702041] Fetched 700 reviews (700 fetched in total)
# ...

# %%
tinder.reviews
# Out:
# [{'date': datetime.datetime(2023, 10, 30, 19, 12, 6),
#   'developerResponse': {'id': 39597992,
#    'body': 'Thank you for sharing this. You can visit our ‘Troubleshooting’ section at gotinder.com/faq to find some articles that might help to resolve your issue. If you can’t find what you’re looking for or if you’re still experiencing issues, please reach out to us at gotinder.com/help and we’ll be happy to help!',
#    'modified': '2023-10-18T18:38:05Z'},
# ...

# %%
tinderdf = pd.DataFrame(np.array(tinder.reviews),columns=['review'])
tinderdf2 = tinderdf.join(pd.DataFrame(tinderdf.pop('review').tolist()))
tinderdf2.head()
# Out:
#                  date                                  developerResponse  \
# 0 2023-10-30 19:12:06  {'id': 39597992, 'body': 'Thank you for sharin...
# 1 2023-11-04 07:16:20                                                NaN
# 2 2023-09-18 14:44:16                                                NaN
# 3 2023-07-19 01:48:04                                                NaN
# 4 2022-11-11 11:49:17                                                NaN
#
#                                               review  rating  isEdited  \
# 0  Thе app is stаndard. If you're loоking for dаt...       5      True
# 1  I spoke to 6 guys over the course of 30 minute...       5     False
# 2  I have been using this app for years now and h...       2     False
# 3  Buyer beware as soon as your payment goes thro...       1     False
# 4  My account was hacked and the hacker must’ve e...       1     False
#
#           userName                                   title
# ...

# %%
tinderdf2.to_csv('C:/Users/Generation UK&I/OneDrive/DATA ANALYTICS/_Portfolio/Bumble/datasets/tinder-apple-reviews.csv')

# %%
from google_play_scraper import app

result = app('com.tinder', lang='en', country='us')
print(result)
# Out:
# {'title': 'Tinder Dating app. Meet People', 'description': "<b>Match, Chat, and Date. That’s our mantra.</b>\r\n\r\nWith 70+ billion matches to date, <b>Tinder® is the top matchmaker dating app,</b>  and the best place to meet new people. Are you looking for true love? An open relationship? Are you looking to get out there and find a date, or do you just want to make friends and chat? With Tinder, you can meet local people everywhere and get the best out of your dating experience:\r\nWhether you're straight, gay, bisexual, or anything in between, Tinder allows you to be who you are and find who you want.\r\nShare your interests and learn more about your matches to get the conversation started, and get the sparks flying.\r\n<b>Photo Verified Profiles:</b>  Because the only surprises we want are flowers on the first date\r\n<b>Video chat:</b> Test your online dating chemistry and meet new people from home!\r\n\r\nTraveling somewhere? Get to know the singles from around the world. Datin
# ...

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tinder',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=3, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.tinder',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.tinder',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
)

# %%
tinderdfg = pd.DataFrame(np.array(result),columns=['review'])
tinderdfg2 = tinderdfg.join(pd.DataFrame(tinderdfg.pop('review').tolist()))
tinderdfg2.head()
# Out:
#                                reviewId       userName  \
# 0  a985ffe4-49f3-456f-9629-a005850c9381   Eric Landrum
# 1  66c62c3b-e6aa-4c13-8186-3039d494a003     J Johnston
# 2  b5be352d-c201-4f4c-9029-6bfa3fd6d2c0      Ben Dobbs
# 3  db08d557-4997-45b5-95fb-ff1744f1b93c  Michael Smyth
# 4  5d0c76fe-165e-48a6-bce8-64b650c0ca7b    chris waltz
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  If you don't pay them for a platinum subscript...      1             41
# 1  Tinder's response is pointless. My problem is ...      1            323
# 2  I feel like this app has gotten significantly ...      1             10
# ...

# %%
tinderdfg2.to_csv('C:/Users/Generation UK&I/OneDrive/DATA ANALYTICS/_Portfolio/Bumble/datasets/tinder-google-reviews.csv')
