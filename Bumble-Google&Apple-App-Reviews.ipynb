# %%
import pandas as pd
import numpy as np
import json

from app_store_scraper import AppStore
bumble = AppStore(country='us', app_name='bumble-dating-meet-people', app_id='930441707')

bumble.review(sleep=1)
# Out:
# 2023-11-16 11:25:45,293 [INFO] Base - Initialised: AppStore('us', 'bumble-dating-meet-people', 930441707)
# 2023-11-16 11:25:45,294 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/bumble-dating-meet-people/id930441707
# 2023-11-16 11:25:51,269 [INFO] Base - [id:930441707] Fetched 100 reviews (100 fetched in total)
# 2023-11-16 11:25:57,823 [INFO] Base - [id:930441707] Fetched 200 reviews (200 fetched in total)
# 2023-11-16 11:26:05,232 [INFO] Base - [id:930441707] Fetched 320 reviews (320 fetched in total)
# 2023-11-16 11:26:11,515 [INFO] Base - [id:930441707] Fetched 420 reviews (420 fetched in total)
# 2023-11-16 11:26:18,572 [INFO] Base - [id:930441707] Fetched 540 reviews (540 fetched in total)
# 2023-11-16 11:26:25,408 [INFO] Base - [id:930441707] Fetched 660 reviews (660 fetched in total)
# 2023-11-16 11:26:31,914 [INFO] Base - [id:930441707] Fetched 780 reviews (780 fetched in total)
# ...

# %%
bumble.reviews
# Out:
# [{'date': datetime.datetime(2023, 3, 10, 6, 17, 48),
#   'developerResponse': {'id': 35331587,
#    'body': "Thank you for your feedback! We're happy to hear you're enjoying Bumble. Do let us know how we could earn that 1 star and make our rating 5 stars. We're curious to find out what we can do. Please drop us a message @BumbleSupport on social media or email us via bumble.com/contact 💛",
#    'modified': '2023-03-12T01:14:38Z'},
# ...

# %%
bumbledf = pd.DataFrame(np.array(bumble.reviews),columns=['review'])
bumbledf2 = bumbledf.join(pd.DataFrame(bumbledf.pop('review').tolist()))
bumbledf2.head()
# Out:
#                  date                                  developerResponse  \
# 0 2023-03-10 06:17:48  {'id': 35331587, 'body': 'Thank you for your f...
# 1 2023-08-15 14:14:55  {'id': 38349729, 'body': 'We're sorry you didn...
# 2 2023-10-24 00:27:38  {'id': 39732944, 'body': 'Thanks for updating ...
# 3 2023-10-18 04:59:51  {'id': 40064892, 'body': 'We're sorry to hear ...
# 4 2021-02-07 22:21:22  {'id': 22222509, 'body': 'You don't have to pa...
#
#                                               review  rating  isEdited  \
# 0  And that’s not saying much. However, I do enjo...       4     False
# 1  When will they figure out how to make swiping ...       2     False
# 2  Telling me I missed a match when I swiped left...       1     False
# 3  I haven’t had much luck with this app, mostly ...       1     False
# 4  This app is good for meeting new people, howev...       3     False
#
#                                  title       userName
# ...

# %%
bumbledf2.to_csv('C:/Users/Generation UK&I/OneDrive/DATA ANALYTICS/_Portfolio/Bumble/datasets/Bumble-apple-reviews.csv')

# %%
from google_play_scraper import app

result = app('com.bumble.app', lang='en', country='us')
print(result)
# Out:
# {'title': 'Bumble: Dating App & Friends', 'description': "<h1>Welcome to <b>Bumble</b> 💛 The community with millions of people to find dates, meet people & make new friends.</h1>\r\n\r\nBumble is a free dating app and social network for singles; the perfect place to meet new people, in an instant. \r\n\r\nWhether you want to find friends, make genuine matches, find meaningful connections, chat with strangers, make new friends, or even expand your professional and social network, we’ve got you covered. \r\n\r\n<b>Changing the rules of dating</b><\r\n\r\nBumble is a free dating app (to download and use) founded on respect, equality, and inclusion. You can find dates, meet up, and meet new people the way you've always done — but on Bumble, women always make the first move. You won’t find that on any other dating apps. \r\n\r\n🕒 With heterosexual matches, women have 24h to start a chat, and men have 24h to respond\r\n💬 Other matches (LGBTQIA+) have 24h to start a chat or reply before the
# ...

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.bumble.app',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=3, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'com.bumble.app',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.bumble.app',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
)

# %%
bumbledfg = pd.DataFrame(np.array(result),columns=['review'])
bumbledfg2 = bumbledfg.join(pd.DataFrame(bumbledfg.pop('review').tolist()))
bumbledfg2.head()
# Out:
#                                reviewId        userName  \
# 0  4ab128af-829b-446b-bb7e-49d85c37e639   Edward Whited
# 1  3091999c-982d-4b5b-9e6c-fcc8471f0d8d   Kasey Lanning
# 2  a169f849-a2b2-4d2e-a2c2-c578266cc803       J Randall
# 3  ea6e45fd-bf1a-4a6f-a027-6c1719a3c686  Michael Fuller
# 4  27c0ac85-1ebd-4533-a75b-eefddf2f8a07    Bodilythrone
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Overall my experience with the app was good. I...      3             11
# 1  App will slow drastically when you start a cha...      1            570
# 2  Bumble used to be good until you had to start ...      1            564
# ...

# %%
bumbledfg2.to_csv('C:/Users/Generation UK&I/OneDrive/DATA ANALYTICS/_Portfolio/Bumble/datasets/Bumble-google-reviews.csv')
