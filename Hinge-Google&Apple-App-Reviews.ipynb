# %%
import pandas as pd
import numpy as np
import json

from app_store_scraper import AppStore
hinge = AppStore(country='us', app_name='hinge-dating-app-match-date', app_id='595287172')

hinge.review(sleep=1)
# Out:
# 2023-11-17 10:18:00,044 [INFO] Base - Initialised: AppStore('us', 'hinge-dating-app-match-date', 595287172)
# 2023-11-17 10:18:00,045 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/us/app/hinge-dating-app-match-date/id595287172
# 2023-11-17 10:18:05,091 [INFO] Base - [id:595287172] Fetched 80 reviews (80 fetched in total)
# 2023-11-17 10:18:11,681 [INFO] Base - [id:595287172] Fetched 200 reviews (200 fetched in total)
# 2023-11-17 10:18:18,096 [INFO] Base - [id:595287172] Fetched 320 reviews (320 fetched in total)
# 2023-11-17 10:18:24,469 [INFO] Base - [id:595287172] Fetched 440 reviews (440 fetched in total)
# 2023-11-17 10:18:30,842 [INFO] Base - [id:595287172] Fetched 560 reviews (560 fetched in total)
# 2023-11-17 10:18:37,229 [INFO] Base - [id:595287172] Fetched 680 reviews (680 fetched in total)
# 2023-11-17 10:18:44,118 [INFO] Base - [id:595287172] Fetched 800 reviews (800 fetched in total)
# ...

# %%
hinge.reviews
# Out:
# [{'date': datetime.datetime(2022, 8, 4, 20, 13, 24),
# ...

# %%
hingedf = pd.DataFrame(np.array(hinge.reviews),columns=['review'])
hingedf2 = hingedf.join(pd.DataFrame(hingedf.pop('review').tolist()))
hingedf2.head()
# Out:
#                  date                                             review  \
# 0 2022-08-04 20:13:24  1) I really like their profile style. It works...
# 1 2021-10-19 00:52:51  Unlike tinder and bumble, Hinge gives you the ...
# 2 2019-05-27 14:15:17  This is, by far, the class of all the availabl...
# 3 2023-06-04 00:08:44  I met my boyfriend with this app. And I am pre...
# 4 2022-09-13 03:19:50  Note to developers: I noticed you stopped tell...
#
#    rating  isEdited                                         title  \
# 0       4     False            Very good, as far as free apps go.
# 1       5     False  Extremely happy, the best choice for singles
# 2       5     False             Pretty sure I met The One on here
# 3       5     False                               Best dating app
# 4       3     False         Good and Bad… Nevertheless a Business
#
#          userName                                  developerResponse
# ...

# %%
hingedf2.to_csv('C:/Users/Generation UK&I/OneDrive/DATA ANALYTICS/_Portfolio/Bumble/datasets/hinge-apple-reviews.csv')

# %%
from google_play_scraper import app

result = app('co.hinge.app', lang='en', country='us')
print(result)
# Out:
# {'title': 'Hinge Dating App: Meet & Date', 'description': '<b>Find a date. Delete our app.</b>\r\nHinge is an inclusive dating app for people who want to get off dating apps for good. That means we’re for real people like you looking to chat, meet people, date and find relationship.\r\n \r\n◼ 3 out of 4 people on Hinge want to go on a second date\r\n◼ #1 mobile-first dating app mentioned in the New York Times wedding section\r\n◼ Fastest growing dating app in the US, UK, Canada, and Australia\r\n◼ Home of viral Voice Prompts\r\n \r\n<b>Dating is hard. We try to make it a little less-hard.</b> ❤️\u200d🔥\r\nThe internet brings people and friends together, but we are here for those who want to meet people to fall in love with. Usually, digital dating puts matches before connecting, in person, where it counts. To change that, we built a dating app designed to be deleted. AKA, a dating app built to get you on actual dates with people who are more than us.\r\n \r\n💌 We quickly learn your t
# ...

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.hinge.app',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=3, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# If you pass `continuation_token` as an argument to the reviews function at this point,
# it will crawl the items after 3 review items.

result, _ = reviews(
    'co.hinge.app',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'co.hinge.app',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
)

# %%
hingedfg = pd.DataFrame(np.array(result),columns=['review'])
hingedfg2 = hingedfg.join(pd.DataFrame(hingedfg.pop('review').tolist()))
hingedfg2.head()
# Out:
#                                reviewId           userName  \
# 0  6edbe633-fe36-4750-bcfd-09478869ead2        Kevin Bates
# 1  1a1bd642-12bf-46ba-8ef4-e760387b5b93        Tom Clemens
# 2  9e173127-569e-45af-97b9-1c9c750b6acb     Ariadne Baxter
# 3  3ecf3c76-7dcf-4efb-a71c-e83d5a3cc8c3            Amy Bos
# 4  efac9aa8-0377-4f0b-8d77-3350a9c9c786  Courtney Pedersen
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  The app works well, and I like their system fi...      3             51
# 1  I've used the app for about a year off and on ...      1             28
# ...

# %%
hingedfg2.to_csv('C:/Users/Generation UK&I/OneDrive/DATA ANALYTICS/_Portfolio/Bumble/datasets/hinge-google-reviews.csv')
